# %% [markdown]
# <a href="https://colab.research.google.com/github/Pealie/TinyML-Exercises/blob/main/Building_a_weather_station_with_TensorFlow_Lite_for_Microcontrollers_Aviemore.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import csv
import datetime
import matplotlib.pyplot as plt
import numpy as np
import os
import pandas as pd
import seaborn as sns
import sklearn.metrics
import tensorflow as tf

from numpy import mean
from numpy import std
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder
from tensorflow.keras import activations
from tensorflow.keras import layers

BATCH_SIZE = 64
MELTING_TEMPERATURE = 2
MIN_SNOW_CM = 0.5 # Above this value, we consider it as snow
NUM_EPOCHS = 20
OUTPUT_DATASET_FILE = "snow_dataset.csv"
TFL_MODEL_FILE = "snow_forecast_model.tflite"
TFL_MODEL_HEADER_FILE = "snow_forecast_model.h"
TF_MODEL = "snow_forecast"

# !pip install wwo-hist

from wwo_hist import retrieve_hist_data # WorldWeatherOnline

frequency=1
api_key = 'your key'
location_list = ['Aviemore']

# retrieve_hist_data returns a list of dataframe(s)
df_weather = retrieve_hist_data(api_key,
                                location_list,
                                '01-JAN-2011',
                                '31-DEC-2022',
                                frequency,
                                location_label = False,
                                export_csv = False,
                                store_df = True)

# Extract temperature, humidity and precipitation
t_list = df_weather[0].tempC.astype(float).to_list()
h_list = df_weather[0].humidity.astype(float).to_list()
s_list = df_weather[0].totalSnow_cm.astype(float).to_list()
     
def binarize(snow, threshold):
  if snow > threshold:
    return 1
  else:
    return 0

s_bin_list = [binarize(snow, MIN_SNOW_CM) for snow in s_list]

cm = plt.cm.get_cmap('gray_r')
plt.figure(dpi=150)
sc = plt.scatter(t_list, h_list, c=s_bin_list, cmap=cm, label="Snow")
plt.colorbar(sc)
plt.legend()
plt.grid(True)
plt.title("Snow(T, H)")
plt.xlabel("Temperature - °C")
plt.ylabel("Humidity - %")
plt.show()

def gen_label(snow, temperature):
  if snow > MIN_SNOW_CM and temperature < MELTING_TEMPERATURE:
    return "Yes"
  else:
    return "No"

snow_labels = [gen_label(snow, temp) for snow, temp in zip(s_list, t_list)]
     
csv_header = ["Temp0", "Temp1", "Temp2", "Humi0", "Humi1", "Humi2", "Snow"]

df_dataset = pd.DataFrame(list(zip(t_list[:-2], t_list[1:-1], t_list[2:], h_list[:-2], h_list[1:-1], h_list[2:], snow_labels[2:])), columns = csv_header)
     
df0 = df_dataset[df_dataset['Snow'] == "No"]
df1 = df_dataset[df_dataset['Snow'] == "Yes"]

num_nosnow_samples_old = round((len(df0.index) / (len(df_dataset.index))) * 100, 2)
num_snow_samples_old   = round((len(df1.index) / (len(df_dataset.index))) * 100, 2)

# Random subsampling of the majority class to guarantee 50% split
if len(df1.index) < len(df0.index):
  df0_sub = df0.sample(len(df1.index))
  df_dataset = pd.concat([df0_sub, df1])
else:
  df1_sub = df1.sample(len(df0.index))
  df_dataset = pd.concat([df1_sub, df0])

df0 = df_dataset[df_dataset['Snow'] == "No"]
df1 = df_dataset[df_dataset['Snow'] == "Yes"]

num_nosnow_samples_new = round((len(df0.index) / (len(df_dataset.index))) * 100, 2)
num_snow_samples_new = round((len(df1.index) / (len(df_dataset.index))) * 100, 2)

# Show number of samples
df_samples_results = pd.DataFrame.from_records(
                [["% No Snow", num_nosnow_samples_old, num_nosnow_samples_new],
                ["% Snow", num_snow_samples_old, num_snow_samples_new]],
            columns = ["Class", "Before - %", "After - %"], index="Class").round(2)

display(df_samples_results)   

# Get all values
t_list = df_dataset['Temp0'].tolist()
h_list = df_dataset['Humi0'].tolist()
t_list = t_list + df_dataset['Temp2'].tail(2).tolist()
h_list = h_list + df_dataset['Humi2'].tail(2).tolist()

# Calculate mean and standard deviation
t_avg = mean(t_list)
h_avg = mean(h_list)
t_std = std(t_list)
h_std = std(h_list)
print("COPY ME!")
print("Temperature - [MEAN, STD]  ", round(t_avg, 5), round(t_std, 5))
print("Humidity - [MEAN, STD]     ", round(h_avg, 5), round(h_std, 5))

# Scaling with Z-score function
def scaling(val, avg, std):
  return (val - avg) / (std)

df_dataset['Temp0'] = df_dataset['Temp0'].apply(lambda x: scaling(x, t_avg, t_std))
df_dataset['Temp1'] = df_dataset['Temp1'].apply(lambda x: scaling(x, t_avg, t_std))
df_dataset['Temp2'] = df_dataset['Temp2'].apply(lambda x: scaling(x, t_avg, t_std))
df_dataset['Humi0'] = df_dataset['Humi0'].apply(lambda x: scaling(x, h_avg, h_std))
df_dataset['Humi1'] = df_dataset['Humi1'].apply(lambda x: scaling(x, h_avg, h_std))
df_dataset['Humi2'] = df_dataset['Humi2'].apply(lambda x: scaling(x, h_avg, h_std))

t_norm_list = df_dataset['Temp0'].tolist()
h_norm_list = df_dataset['Humi0'].tolist()
t_norm_list = t_norm_list + df_dataset['Temp2'].tail(2).tolist()
h_norm_list = h_norm_list + df_dataset['Humi2'].tail(2).tolist()

fig, ax=plt.subplots(1,2)
plt.subplots_adjust(wspace = 0.4)
sns.distplot(t_list, ax=ax[0])
ax[0].set_title("Un-normalized temperature")
sns.distplot(h_list, ax=ax[1])
ax[1].set_title("Un-normalized humidity")

fig, ax=plt.subplots(1,2)
plt.subplots_adjust(wspace = 0.5)
sns.distplot(t_norm_list, ax=ax[0])
ax[0].set_title("Normalized temperature")
sns.distplot(h_norm_list, ax=ax[1])
ax[1].set_title("Normalized humidity")


df_dataset.to_csv(OUTPUT_DATASET_FILE, index=False)

f_names = df_dataset.columns.values[0:6]
l_name  = df_dataset.columns.values[6:7]
x = df_dataset[f_names]
y = df_dataset[l_name]

labelencoder = LabelEncoder()
labelencoder.fit(y.Snow)
y_encoded = labelencoder.transform(y.Snow)

# Split 1 (85% vs 15%)
x_train, x_validate_test, y_train, y_validate_test = train_test_split(x, y_encoded, test_size=0.15, random_state = 1)
# Split 2 (50% vs 50%)
x_test, x_validate, y_test, y_validate = train_test_split(x_validate_test, y_validate_test, test_size=0.50, random_state = 3)
     
model = tf.keras.Sequential()
model.add(layers.Dense(12, activation='relu', input_shape=(len(f_names),)))
model.add(layers.Dropout(0.2))
model.add(layers.Dense(1, activation='sigmoid'))
model.summary()

model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])

history = model.fit(x_train, y_train, epochs=NUM_EPOCHS, batch_size=BATCH_SIZE, validation_data=(x_validate, y_validate))
     
loss_train = history.history['loss']
loss_val   = history.history['val_loss']
acc_train  = history.history['accuracy']
acc_val    = history.history['val_accuracy']
epochs     = range(1, NUM_EPOCHS + 1)

def plot_train_val_history(x, y_train, y_val, type_txt):
  plt.figure(figsize = (10,7))
  plt.plot(x, y_train, 'g', label='Training'+type_txt)
  plt.plot(x, y_val, 'b', label='Validation'+type_txt)
  plt.title('Training and Validation'+type_txt)
  plt.xlabel('Epochs')
  plt.ylabel(type_txt)
  plt.legend()
  plt.show()

plot_train_val_history(epochs, loss_train, loss_val, "Loss")
plot_train_val_history(epochs, acc_train, acc_val, "Accuracy")
     
model.save(TF_MODEL)

y_test_pred = model.predict(x_test)

y_test_pred = (y_test_pred > 0.5).astype("int32")

cm = sklearn.metrics.confusion_matrix(y_test, y_test_pred)

index_names  = ["Actual No Snow", "Actual Snow"]
column_names = ["Predicted No Snow", "Predicted Snow"]

df_cm = pd.DataFrame(cm, index = index_names, columns = column_names)

plt.figure(figsize = (10,7))
sns.heatmap(df_cm, annot=True, fmt='d', cmap="Blues")
plt.figure(figsize = (10,7))

TN = cm[0][0]
TP = cm[1][1]
FN = cm[1][0]
FP = cm[0][1]

accuracy = (TP + TN) / (TP + TN + FN + FP)
precision = TP / (TP + FP)
recall = TP / (TP + FN)
f_score = (2 * recall * precision) / (recall + precision)

print("Accuracy:  ", round(accuracy, 3))
print("Recall:    ", round(recall, 3))
print("Precision: ", round(precision, 3))
print("F-score:   ", round(f_score, 3))

def representative_data_gen():
  for i_value in tf.data.Dataset.from_tensor_slices(x_test).batch(1).take(100):
    i_value_f32 = tf.dtypes.cast(i_value, tf.float32)
    yield [i_value_f32]

converter = tf.lite.TFLiteConverter.from_saved_model(TF_MODEL)

converter.representative_dataset = tf.lite.RepresentativeDataset(representative_data_gen)
converter.optimizations = [tf.lite.Optimize.DEFAULT]
converter.target_spec.supported_ops = [tf.lite.OpsSet.TFLITE_BUILTINS_INT8]
converter.inference_input_type = tf.int8
converter.inference_output_type = tf.int8

tflite_model_quant = converter.convert()
open(TFL_MODEL_FILE, "wb").write(tflite_model_quant)

# !apt-get update && apt-get -qq install xxd
# !xxd -i snow_forecast_model.tflite > model.h
# !cat model.h
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting wwo-hist
#   Downloading wwo_hist-0.0.7-py3-none-any.whl (4.6 kB)
# Installing collected packages: wwo-hist
# Successfully installed wwo-hist-0.0.7
#
#
# Retrieving weather data for Aviemore
#
#
# Currently retrieving data for Aviemore: from 2011-01-01 to 2011-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:01.758444
# Currently retrieving data for Aviemore: from 2011-02-01 to 2011-02-28
# Time elapsed (hh:mm:ss.ms) 0:00:03.381871
# Currently retrieving data for Aviemore: from 2011-03-01 to 2011-03-31
# Time elapsed (hh:mm:ss.ms) 0:00:05.107606
# Currently retrieving data for Aviemore: from 2011-04-01 to 2011-04-30
# Time elapsed (hh:mm:ss.ms) 0:00:06.882374
# Currently retrieving data for Aviemore: from 2011-05-01 to 2011-05-31
# Time elapsed (hh:mm:ss.ms) 0:00:08.559679
# Currently retrieving data for Aviemore: from 2011-06-01 to 2011-06-30
# Time elapsed (hh:mm:ss.ms) 0:00:10.359733
# Currently retrieving data for Aviemore: from 2011-07-01 to 2011-07-31
# Time elapsed (hh:mm:ss.ms) 0:00:12.166146
# Currently retrieving data for Aviemore: from 2011-08-01 to 2011-08-31
# Time elapsed (hh:mm:ss.ms) 0:00:13.888029
# Currently retrieving data for Aviemore: from 2011-09-01 to 2011-09-30
# Time elapsed (hh:mm:ss.ms) 0:00:15.542955
# Currently retrieving data for Aviemore: from 2011-10-01 to 2011-10-31
# Time elapsed (hh:mm:ss.ms) 0:00:17.321155
# Currently retrieving data for Aviemore: from 2011-11-01 to 2011-11-30
# Time elapsed (hh:mm:ss.ms) 0:00:19.023655
# Currently retrieving data for Aviemore: from 2011-12-01 to 2011-12-31
# Time elapsed (hh:mm:ss.ms) 0:00:20.686183
# Currently retrieving data for Aviemore: from 2012-01-01 to 2012-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:22.296432
# Currently retrieving data for Aviemore: from 2012-02-01 to 2012-02-29
# Time elapsed (hh:mm:ss.ms) 0:00:24.073319
# Currently retrieving data for Aviemore: from 2012-03-01 to 2012-03-31
# Time elapsed (hh:mm:ss.ms) 0:00:25.688155
# Currently retrieving data for Aviemore: from 2012-04-01 to 2012-04-30
# Time elapsed (hh:mm:ss.ms) 0:00:27.439174
# Currently retrieving data for Aviemore: from 2012-05-01 to 2012-05-31
# Time elapsed (hh:mm:ss.ms) 0:00:29.081625
# Currently retrieving data for Aviemore: from 2012-06-01 to 2012-06-30
# Time elapsed (hh:mm:ss.ms) 0:00:30.731229
# Currently retrieving data for Aviemore: from 2012-07-01 to 2012-07-31
# Time elapsed (hh:mm:ss.ms) 0:00:33.019829
# Currently retrieving data for Aviemore: from 2012-08-01 to 2012-08-31
# Time elapsed (hh:mm:ss.ms) 0:00:34.704334
# Currently retrieving data for Aviemore: from 2012-09-01 to 2012-09-30
# Time elapsed (hh:mm:ss.ms) 0:00:36.482170
# Currently retrieving data for Aviemore: from 2012-10-01 to 2012-10-31
# Time elapsed (hh:mm:ss.ms) 0:00:38.142537
# Currently retrieving data for Aviemore: from 2012-11-01 to 2012-11-30
# Time elapsed (hh:mm:ss.ms) 0:00:39.860863
# Currently retrieving data for Aviemore: from 2012-12-01 to 2012-12-31
# Time elapsed (hh:mm:ss.ms) 0:00:41.518020
# Currently retrieving data for Aviemore: from 2013-01-01 to 2013-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:43.188432
# Currently retrieving data for Aviemore: from 2013-02-01 to 2013-02-28
# Time elapsed (hh:mm:ss.ms) 0:00:44.767019
# Currently retrieving data for Aviemore: from 2013-03-01 to 2013-03-31
# Time elapsed (hh:mm:ss.ms) 0:00:46.550296
# Currently retrieving data for Aviemore: from 2013-04-01 to 2013-04-30
# Time elapsed (hh:mm:ss.ms) 0:00:48.209964
# Currently retrieving data for Aviemore: from 2013-05-01 to 2013-05-31
# Time elapsed (hh:mm:ss.ms) 0:00:49.914506
# Currently retrieving data for Aviemore: from 2013-06-01 to 2013-06-30
# Time elapsed (hh:mm:ss.ms) 0:00:51.549974
# Currently retrieving data for Aviemore: from 2013-07-01 to 2013-07-31
# Time elapsed (hh:mm:ss.ms) 0:00:53.384711
# Currently retrieving data for Aviemore: from 2013-08-01 to 2013-08-31
# Time elapsed (hh:mm:ss.ms) 0:00:55.114962
# Currently retrieving data for Aviemore: from 2013-09-01 to 2013-09-30
# Time elapsed (hh:mm:ss.ms) 0:00:56.963907
# Currently retrieving data for Aviemore: from 2013-10-01 to 2013-10-31
# Time elapsed (hh:mm:ss.ms) 0:00:58.798977
# Currently retrieving data for Aviemore: from 2013-11-01 to 2013-11-30
# Time elapsed (hh:mm:ss.ms) 0:01:00.601918
# Currently retrieving data for Aviemore: from 2013-12-01 to 2013-12-31
# Time elapsed (hh:mm:ss.ms) 0:01:02.466986
# Currently retrieving data for Aviemore: from 2014-01-01 to 2014-01-31
# Time elapsed (hh:mm:ss.ms) 0:01:04.135324
# Currently retrieving data for Aviemore: from 2014-02-01 to 2014-02-28
# Time elapsed (hh:mm:ss.ms) 0:01:05.826905
# Currently retrieving data for Aviemore: from 2014-03-01 to 2014-03-31
# Time elapsed (hh:mm:ss.ms) 0:01:07.780670
# Currently retrieving data for Aviemore: from 2014-04-01 to 2014-04-30
# Time elapsed (hh:mm:ss.ms) 0:01:09.549522
# Currently retrieving data for Aviemore: from 2014-05-01 to 2014-05-31
# Time elapsed (hh:mm:ss.ms) 0:01:11.276879
# Currently retrieving data for Aviemore: from 2014-06-01 to 2014-06-30
# Time elapsed (hh:mm:ss.ms) 0:01:13.416830
# Currently retrieving data for Aviemore: from 2014-07-01 to 2014-07-31
# Time elapsed (hh:mm:ss.ms) 0:01:15.362779
# Currently retrieving data for Aviemore: from 2014-08-01 to 2014-08-31
# Time elapsed (hh:mm:ss.ms) 0:01:17.525741
# Currently retrieving data for Aviemore: from 2014-09-01 to 2014-09-30
# Time elapsed (hh:mm:ss.ms) 0:01:20.013222
# Currently retrieving data for Aviemore: from 2014-10-01 to 2014-10-31
# Time elapsed (hh:mm:ss.ms) 0:01:22.183846
# Currently retrieving data for Aviemore: from 2014-11-01 to 2014-11-30
# Time elapsed (hh:mm:ss.ms) 0:01:24.597008
# Currently retrieving data for Aviemore: from 2014-12-01 to 2014-12-31
# Time elapsed (hh:mm:ss.ms) 0:01:26.916194
# Currently retrieving data for Aviemore: from 2015-01-01 to 2015-01-31
# Time elapsed (hh:mm:ss.ms) 0:01:29.503621
# Currently retrieving data for Aviemore: from 2015-02-01 to 2015-02-28
# Time elapsed (hh:mm:ss.ms) 0:01:31.234205
# Currently retrieving data for Aviemore: from 2015-03-01 to 2015-03-31
# Time elapsed (hh:mm:ss.ms) 0:01:33.163752
# Currently retrieving data for Aviemore: from 2015-04-01 to 2015-04-30
# Time elapsed (hh:mm:ss.ms) 0:01:35.040305
# Currently retrieving data for Aviemore: from 2015-05-01 to 2015-05-31
# Time elapsed (hh:mm:ss.ms) 0:01:36.839162
# Currently retrieving data for Aviemore: from 2015-06-01 to 2015-06-30
# Time elapsed (hh:mm:ss.ms) 0:01:38.666531
# Currently retrieving data for Aviemore: from 2015-07-01 to 2015-07-31
# Time elapsed (hh:mm:ss.ms) 0:01:40.263251
# Currently retrieving data for Aviemore: from 2015-08-01 to 2015-08-31
# Time elapsed (hh:mm:ss.ms) 0:01:42.038815
# Currently retrieving data for Aviemore: from 2015-09-01 to 2015-09-30
# Time elapsed (hh:mm:ss.ms) 0:01:43.849319
# Currently retrieving data for Aviemore: from 2015-10-01 to 2015-10-31
# Time elapsed (hh:mm:ss.ms) 0:01:45.516418
# Currently retrieving data for Aviemore: from 2015-11-01 to 2015-11-30
# Time elapsed (hh:mm:ss.ms) 0:01:47.421326
# Currently retrieving data for Aviemore: from 2015-12-01 to 2015-12-31
# Time elapsed (hh:mm:ss.ms) 0:01:49.072414
# Currently retrieving data for Aviemore: from 2016-01-01 to 2016-01-31
# Time elapsed (hh:mm:ss.ms) 0:01:50.945131
# Currently retrieving data for Aviemore: from 2016-02-01 to 2016-02-29
# Time elapsed (hh:mm:ss.ms) 0:01:52.567649
# Currently retrieving data for Aviemore: from 2016-03-01 to 2016-03-31
# Time elapsed (hh:mm:ss.ms) 0:01:54.519153
# Currently retrieving data for Aviemore: from 2016-04-01 to 2016-04-30
# Time elapsed (hh:mm:ss.ms) 0:01:56.267366
# Currently retrieving data for Aviemore: from 2016-05-01 to 2016-05-31
# Time elapsed (hh:mm:ss.ms) 0:01:57.970896
# Currently retrieving data for Aviemore: from 2016-06-01 to 2016-06-30
# Time elapsed (hh:mm:ss.ms) 0:01:59.614601
# Currently retrieving data for Aviemore: from 2016-07-01 to 2016-07-31
# Time elapsed (hh:mm:ss.ms) 0:02:01.273724
# Currently retrieving data for Aviemore: from 2016-08-01 to 2016-08-31
# Time elapsed (hh:mm:ss.ms) 0:02:03.116942
# Currently retrieving data for Aviemore: from 2016-09-01 to 2016-09-30
# Time elapsed (hh:mm:ss.ms) 0:02:04.830371
# Currently retrieving data for Aviemore: from 2016-10-01 to 2016-10-31
# Time elapsed (hh:mm:ss.ms) 0:02:06.524855
# Currently retrieving data for Aviemore: from 2016-11-01 to 2016-11-30
# Time elapsed (hh:mm:ss.ms) 0:02:08.361205
# Currently retrieving data for Aviemore: from 2016-12-01 to 2016-12-31
# Time elapsed (hh:mm:ss.ms) 0:02:10.096685
# Currently retrieving data for Aviemore: from 2017-01-01 to 2017-01-31
# Time elapsed (hh:mm:ss.ms) 0:02:12.005914
# Currently retrieving data for Aviemore: from 2017-02-01 to 2017-02-28
# Time elapsed (hh:mm:ss.ms) 0:02:13.684001
# Currently retrieving data for Aviemore: from 2017-03-01 to 2017-03-31
# Time elapsed (hh:mm:ss.ms) 0:02:15.503000
# Currently retrieving data for Aviemore: from 2017-04-01 to 2017-04-30
# Time elapsed (hh:mm:ss.ms) 0:02:17.414393
# Currently retrieving data for Aviemore: from 2017-05-01 to 2017-05-31
# Time elapsed (hh:mm:ss.ms) 0:02:19.126937
# Currently retrieving data for Aviemore: from 2017-06-01 to 2017-06-30
# Time elapsed (hh:mm:ss.ms) 0:02:20.800902
# Currently retrieving data for Aviemore: from 2017-07-01 to 2017-07-31
# Time elapsed (hh:mm:ss.ms) 0:02:22.605861
# Currently retrieving data for Aviemore: from 2017-08-01 to 2017-08-31
# Time elapsed (hh:mm:ss.ms) 0:02:24.441631
# Currently retrieving data for Aviemore: from 2017-09-01 to 2017-09-30
# Time elapsed (hh:mm:ss.ms) 0:02:26.376404
# Currently retrieving data for Aviemore: from 2017-10-01 to 2017-10-31
# Time elapsed (hh:mm:ss.ms) 0:02:28.505100
# Currently retrieving data for Aviemore: from 2017-11-01 to 2017-11-30
# Time elapsed (hh:mm:ss.ms) 0:02:30.304631
# Currently retrieving data for Aviemore: from 2017-12-01 to 2017-12-31
# Time elapsed (hh:mm:ss.ms) 0:02:32.110562
# Currently retrieving data for Aviemore: from 2018-01-01 to 2018-01-31
# Time elapsed (hh:mm:ss.ms) 0:02:33.785876
# Currently retrieving data for Aviemore: from 2018-02-01 to 2018-02-28
# Time elapsed (hh:mm:ss.ms) 0:02:35.427079
# Currently retrieving data for Aviemore: from 2018-03-01 to 2018-03-31
# Time elapsed (hh:mm:ss.ms) 0:02:37.209764
# Currently retrieving data for Aviemore: from 2018-04-01 to 2018-04-30
# Time elapsed (hh:mm:ss.ms) 0:02:39.009322
# Currently retrieving data for Aviemore: from 2018-05-01 to 2018-05-31
# Time elapsed (hh:mm:ss.ms) 0:02:40.876855
# Currently retrieving data for Aviemore: from 2018-06-01 to 2018-06-30
# Time elapsed (hh:mm:ss.ms) 0:02:42.557726
# Currently retrieving data for Aviemore: from 2018-07-01 to 2018-07-31
# Time elapsed (hh:mm:ss.ms) 0:02:44.234599
# Currently retrieving data for Aviemore: from 2018-08-01 to 2018-08-31
# Time elapsed (hh:mm:ss.ms) 0:02:46.025116
# Currently retrieving data for Aviemore: from 2018-09-01 to 2018-09-30
# Time elapsed (hh:mm:ss.ms) 0:02:47.686502
# Currently retrieving data for Aviemore: from 2018-10-01 to 2018-10-31
# Time elapsed (hh:mm:ss.ms) 0:02:49.368526
# Currently retrieving data for Aviemore: from 2018-11-01 to 2018-11-30
# Time elapsed (hh:mm:ss.ms) 0:02:51.166515
# Currently retrieving data for Aviemore: from 2018-12-01 to 2018-12-31
# Time elapsed (hh:mm:ss.ms) 0:02:52.879344
# Currently retrieving data for Aviemore: from 2019-01-01 to 2019-01-31
# Time elapsed (hh:mm:ss.ms) 0:02:54.695895
# Currently retrieving data for Aviemore: from 2019-02-01 to 2019-02-28
# Time elapsed (hh:mm:ss.ms) 0:02:56.374796
# Currently retrieving data for Aviemore: from 2019-03-01 to 2019-03-31
# Time elapsed (hh:mm:ss.ms) 0:02:58.231831
# Currently retrieving data for Aviemore: from 2019-04-01 to 2019-04-30
# Time elapsed (hh:mm:ss.ms) 0:02:59.795241
# Currently retrieving data for Aviemore: from 2019-05-01 to 2019-05-31
# Time elapsed (hh:mm:ss.ms) 0:03:01.488308
# Currently retrieving data for Aviemore: from 2019-06-01 to 2019-06-30
# Time elapsed (hh:mm:ss.ms) 0:03:03.192468
# Currently retrieving data for Aviemore: from 2019-07-01 to 2019-07-31
# Time elapsed (hh:mm:ss.ms) 0:03:05.047966
# Currently retrieving data for Aviemore: from 2019-08-01 to 2019-08-31
# Time elapsed (hh:mm:ss.ms) 0:03:06.915633
# Currently retrieving data for Aviemore: from 2019-09-01 to 2019-09-30
# Time elapsed (hh:mm:ss.ms) 0:03:08.701453
# Currently retrieving data for Aviemore: from 2019-10-01 to 2019-10-31
# Time elapsed (hh:mm:ss.ms) 0:03:11.829968
# Currently retrieving data for Aviemore: from 2019-11-01 to 2019-11-30
# Time elapsed (hh:mm:ss.ms) 0:03:13.684806
# Currently retrieving data for Aviemore: from 2019-12-01 to 2019-12-31
# Time elapsed (hh:mm:ss.ms) 0:03:15.426212
# Currently retrieving data for Aviemore: from 2020-01-01 to 2020-01-31
# Time elapsed (hh:mm:ss.ms) 0:03:17.184301
# Currently retrieving data for Aviemore: from 2020-02-01 to 2020-02-29
# Time elapsed (hh:mm:ss.ms) 0:03:18.880405
# Currently retrieving data for Aviemore: from 2020-03-01 to 2020-03-31
# Time elapsed (hh:mm:ss.ms) 0:03:20.694656
# Currently retrieving data for Aviemore: from 2020-04-01 to 2020-04-30
# Time elapsed (hh:mm:ss.ms) 0:03:22.333060
# Currently retrieving data for Aviemore: from 2020-05-01 to 2020-05-31
# Time elapsed (hh:mm:ss.ms) 0:03:24.051259
# Currently retrieving data for Aviemore: from 2020-06-01 to 2020-06-30
# Time elapsed (hh:mm:ss.ms) 0:03:25.744729
# Currently retrieving data for Aviemore: from 2020-07-01 to 2020-07-31
# Time elapsed (hh:mm:ss.ms) 0:03:27.452501
# Currently retrieving data for Aviemore: from 2020-08-01 to 2020-08-31
# Time elapsed (hh:mm:ss.ms) 0:03:29.235503
# Currently retrieving data for Aviemore: from 2020-09-01 to 2020-09-30
# Time elapsed (hh:mm:ss.ms) 0:03:32.422188
# Currently retrieving data for Aviemore: from 2020-10-01 to 2020-10-31
# Time elapsed (hh:mm:ss.ms) 0:03:34.542168
# Currently retrieving data for Aviemore: from 2020-11-01 to 2020-11-30
# Time elapsed (hh:mm:ss.ms) 0:03:36.245313
# Currently retrieving data for Aviemore: from 2020-12-01 to 2020-12-31
# Time elapsed (hh:mm:ss.ms) 0:03:38.223739
# Currently retrieving data for Aviemore: from 2021-01-01 to 2021-01-31
# Time elapsed (hh:mm:ss.ms) 0:03:40.042206
# Currently retrieving data for Aviemore: from 2021-02-01 to 2021-02-28
# Time elapsed (hh:mm:ss.ms) 0:03:41.741745
# Currently retrieving data for Aviemore: from 2021-03-01 to 2021-03-31
# Time elapsed (hh:mm:ss.ms) 0:03:44.000972
# Currently retrieving data for Aviemore: from 2021-04-01 to 2021-04-30
# Time elapsed (hh:mm:ss.ms) 0:03:45.691149
# Currently retrieving data for Aviemore: from 2021-05-01 to 2021-05-31
# Time elapsed (hh:mm:ss.ms) 0:03:47.866756
# Currently retrieving data for Aviemore: from 2021-06-01 to 2021-06-30
# Time elapsed (hh:mm:ss.ms) 0:03:49.816075
# Currently retrieving data for Aviemore: from 2021-07-01 to 2021-07-31
# Time elapsed (hh:mm:ss.ms) 0:03:51.600648
# Currently retrieving data for Aviemore: from 2021-08-01 to 2021-08-31
# Time elapsed (hh:mm:ss.ms) 0:03:53.523021
# Currently retrieving data for Aviemore: from 2021-09-01 to 2021-09-30
# Time elapsed (hh:mm:ss.ms) 0:03:55.214953
# Currently retrieving data for Aviemore: from 2021-10-01 to 2021-10-31
# Time elapsed (hh:mm:ss.ms) 0:03:56.972564
# Currently retrieving data for Aviemore: from 2021-11-01 to 2021-11-30
# Time elapsed (hh:mm:ss.ms) 0:03:58.733854
# Currently retrieving data for Aviemore: from 2021-12-01 to 2021-12-31
# Time elapsed (hh:mm:ss.ms) 0:04:00.593157
# Currently retrieving data for Aviemore: from 2022-01-01 to 2022-01-31
# Time elapsed (hh:mm:ss.ms) 0:04:02.427795
# Currently retrieving data for Aviemore: from 2022-02-01 to 2022-02-28
# Time elapsed (hh:mm:ss.ms) 0:04:04.041387
# Currently retrieving data for Aviemore: from 2022-03-01 to 2022-03-31
# Time elapsed (hh:mm:ss.ms) 0:04:05.743332
# Currently retrieving data for Aviemore: from 2022-04-01 to 2022-04-30
# Time elapsed (hh:mm:ss.ms) 0:04:07.811943
# Currently retrieving data for Aviemore: from 2022-05-01 to 2022-05-31
# Time elapsed (hh:mm:ss.ms) 0:04:09.643387
# Currently retrieving data for Aviemore: from 2022-06-01 to 2022-06-30
# Time elapsed (hh:mm:ss.ms) 0:04:11.489990
# Currently retrieving data for Aviemore: from 2022-07-01 to 2022-07-31
# Time elapsed (hh:mm:ss.ms) 0:04:13.262709
# Currently retrieving data for Aviemore: from 2022-08-01 to 2022-08-31
# Time elapsed (hh:mm:ss.ms) 0:04:14.956482
# Currently retrieving data for Aviemore: from 2022-09-01 to 2022-09-30
# Time elapsed (hh:mm:ss.ms) 0:04:16.613066
# Currently retrieving data for Aviemore: from 2022-10-01 to 2022-10-31
# Time elapsed (hh:mm:ss.ms) 0:04:18.449927
# Currently retrieving data for Aviemore: from 2022-11-01 to 2022-11-30
# Time elapsed (hh:mm:ss.ms) 0:04:20.142660
# Currently retrieving data for Aviemore: from 2022-12-01 to 2022-12-31
# Time elapsed (hh:mm:ss.ms) 0:04:21.945778
#            Before - %  After - %
# Class
# % No Snow       93.95       50.0
# % Snow           6.05       50.0
# COPY ME!
# Temperature - [MEAN, STD]   3.10655 5.62127
# Humidity - [MEAN, STD]      88.10733 9.22738
# /usr/local/lib/python3.8/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# /usr/local/lib/python3.8/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# /usr/local/lib/python3.8/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# /usr/local/lib/python3.8/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 12)                84
#
#  dropout (Dropout)           (None, 12)                0
#
#  dense_1 (Dense)             (None, 1)                 13
#
# =================================================================
# Total params: 97
# Trainable params: 97
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/20
# 170/170 [==============================] - 1s 3ms/step - loss: 0.5351 - accuracy: 0.7415 - val_loss: 0.3895 - val_accuracy: 0.8766
# Epoch 2/20
# 170/170 [==============================] - 0s 2ms/step - loss: 0.3612 - accuracy: 0.8772 - val_loss: 0.3126 - val_accuracy: 0.9027
# Epoch 3/20
# 170/170 [==============================] - 0s 2ms/step - loss: 0.3126 - accuracy: 0.8990 - val_loss: 0.2842 - val_accuracy: 0.9100
# Epoch 4/20
# 170/170 [==============================] - 0s 2ms/step - loss: 0.2937 - accuracy: 0.9064 - val_loss: 0.2710 - val_accuracy: 0.9205
# Epoch 5/20
# 170/170 [==============================] - 0s 2ms/step - loss: 0.2798 - accuracy: 0.9097 - val_loss: 0.2626 - val_accuracy: 0.9247
# Epoch 6/20
# 170/170 [==============================] - 0s 2ms/step - loss: 0.2751 - accuracy: 0.9117 - val_loss: 0.2563 - val_accuracy: 0.9257
# Epoch 7/20
# 170/170 [==============================] - 0s 2ms/step - loss: 0.2683 - accuracy: 0.9134 - val_loss: 0.2511 - val_accuracy: 0.9247
# Epoch 8/20
# 170/170 [==============================] - 0s 2ms/step - loss: 0.2637 - accuracy: 0.9150 - val_loss: 0.2465 - val_accuracy: 0.9257
# Epoch 9/20
# 170/170 [==============================] - 0s 2ms/step - loss: 0.2585 - accuracy: 0.9167 - val_loss: 0.2429 - val_accuracy: 0.9247
# Epoch 10/20
# 170/170 [==============================] - 0s 2ms/step - loss: 0.2518 - accuracy: 0.9167 - val_loss: 0.2396 - val_accuracy: 0.9247
# Epoch 11/20
# 170/170 [==============================] - 0s 2ms/step - loss: 0.2499 - accuracy: 0.9194 - val_loss: 0.2366 - val_accuracy: 0.9278
# Epoch 12/20
# 170/170 [==============================] - 0s 2ms/step - loss: 0.2477 - accuracy: 0.9180 - val_loss: 0.2347 - val_accuracy: 0.9268
# Epoch 13/20
# 170/170 [==============================] - 0s 2ms/step - loss: 0.2458 - accuracy: 0.9204 - val_loss: 0.2322 - val_accuracy: 0.9278
# Epoch 14/20
# 170/170 [==============================] - 0s 2ms/step - loss: 0.2421 - accuracy: 0.9210 - val_loss: 0.2300 - val_accuracy: 0.9278
# Epoch 15/20
# 170/170 [==============================] - 0s 2ms/step - loss: 0.2380 - accuracy: 0.9216 - val_loss: 0.2280 - val_accuracy: 0.9278
# Epoch 16/20
# 170/170 [==============================] - 0s 2ms/step - loss: 0.2383 - accuracy: 0.9208 - val_loss: 0.2264 - val_accuracy: 0.9278
# Epoch 17/20
# 170/170 [==============================] - 0s 2ms/step - loss: 0.2361 - accuracy: 0.9237 - val_loss: 0.2251 - val_accuracy: 0.9289
# Epoch 18/20
# 170/170 [==============================] - 0s 2ms/step - loss: 0.2342 - accuracy: 0.9240 - val_loss: 0.2233 - val_accuracy: 0.9278
# Epoch 19/20
# 170/170 [==============================] - 0s 2ms/step - loss: 0.2336 - accuracy: 0.9239 - val_loss: 0.2219 - val_accuracy: 0.9289
# Epoch 20/20
# 170/170 [==============================] - 0s 2ms/step - loss: 0.2310 - accuracy: 0.9246 - val_loss: 0.2205 - val_accuracy: 0.9310
# 30/30 [==============================] - 0s 1ms/step
# Accuracy:   0.924
# Recall:     0.99
# Precision:  0.875
# F-score:    0.929
# Ign:1 https://developer.download.nvidia.com/compute/machine-learning/repos/ubuntu1804/x86_64  InRelease
# Hit:2 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu1804/x86_64  InRelease
# Get:3 https://cloud.r-project.org/bin/linux/ubuntu bionic-cran40/ InRelease [3,626 B]
# Hit:4 http://archive.ubuntu.com/ubuntu bionic InRelease
# Hit:5 https://developer.download.nvidia.com/compute/machine-learning/repos/ubuntu1804/x86_64  Release
# Get:6 http://archive.ubuntu.com/ubuntu bionic-updates InRelease [88.7 kB]
# Get:7 http://security.ubuntu.com/ubuntu bionic-security InRelease [88.7 kB]
# Hit:8 http://ppa.launchpad.net/c2d4u.team/c2d4u4.0+/ubuntu bionic InRelease
# Get:9 http://archive.ubuntu.com/ubuntu bionic-backports InRelease [83.3 kB]
# Hit:10 http://ppa.launchpad.net/cran/libgit2/ubuntu bionic InRelease
# Hit:11 http://ppa.launchpad.net/deadsnakes/ppa/ubuntu bionic InRelease
# Hit:13 http://ppa.launchpad.net/graphics-drivers/ppa/ubuntu bionic InRelease
# Get:14 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 Packages [3,569 kB]
# Get:15 http://archive.ubuntu.com/ubuntu bionic-updates/universe amd64 Packages [2,348 kB]
# Get:16 http://archive.ubuntu.com/ubuntu bionic-updates/restricted amd64 Packages [1,412 kB]
# Get:17 http://security.ubuntu.com/ubuntu bionic-security/main amd64 Packages [3,141 kB]
# Get:18 http://security.ubuntu.com/ubuntu bionic-security/restricted amd64 Packages [1,369 kB]
# Get:19 http://security.ubuntu.com/ubuntu bionic-security/universe amd64 Packages [1,573 kB]
# Fetched 13.7 MB in 4s (3,550 kB/s)
# Reading package lists... Done
# (Reading database ... 124016 files and directories currently installed.)
# Preparing to unpack .../xxd_2%3a8.0.1453-1ubuntu1.10_amd64.deb ...
# Unpacking xxd (2:8.0.1453-1ubuntu1.10) over (2:8.0.1453-1ubuntu1.9) ...
# Setting up xxd (2:8.0.1453-1ubuntu1.10) ...
# Processing triggers for man-db (2.8.3-2ubuntu0.1) ...
# unsigned char snow_forecast_model_tflite[] = {
#   0x1c, 0x00, 0x00, 0x00, 0x54, 0x46, 0x4c, 0x33, 0x14, 0x00, 0x20, 0x00,
#   0x1c, 0x00, 0x18, 0x00, 0x14, 0x00, 0x10, 0x00, 0x0c, 0x00, 0x00, 0x00,
#   0x08, 0x00, 0x04, 0x00, 0x14, 0x00, 0x00, 0x00, 0x1c, 0x00, 0x00, 0x00,
#   0x84, 0x00, 0x00, 0x00, 0xdc, 0x00, 0x00, 0x00, 0x5c, 0x02, 0x00, 0x00,
#   0x6c, 0x02, 0x00, 0x00, 0x8c, 0x07, 0x00, 0x00, 0x03, 0x00, 0x00, 0x00,
#   0x01, 0x00, 0x00, 0x00, 0x04, 0x00, 0x00, 0x00, 0x5a, 0xfd, 0xff, 0xff,
#   0x0c, 0x00, 0x00, 0x00, 0x1c, 0x00, 0x00, 0x00, 0x38, 0x00, 0x00, 0x00,
#   0x0f, 0x00, 0x00, 0x00, 0x73, 0x65, 0x72, 0x76, 0x69, 0x6e, 0x67, 0x5f,
#   0x64, 0x65, 0x66, 0x61, 0x75, 0x6c, 0x74, 0x00, 0x01, 0x00, 0x00, 0x00,
#   0x04, 0x00, 0x00, 0x00, 0x98, 0xff, 0xff, 0xff, 0x07, 0x00, 0x00, 0x00,
#   0x04, 0x00, 0x00, 0x00, 0x07, 0x00, 0x00, 0x00, 0x64, 0x65, 0x6e, 0x73,
#   0x65, 0x5f, 0x31, 0x00, 0x01, 0x00, 0x00, 0x00, 0x04, 0x00, 0x00, 0x00,
#   0x6a, 0xfe, 0xff, 0xff, 0x04, 0x00, 0x00, 0x00, 0x0b, 0x00, 0x00, 0x00,
#   0x64, 0x65, 0x6e, 0x73, 0x65, 0x5f, 0x69, 0x6e, 0x70, 0x75, 0x74, 0x00,
#   0x02, 0x00, 0x00, 0x00, 0x34, 0x00, 0x00, 0x00, 0x04, 0x00, 0x00, 0x00,
#   0xdc, 0xff, 0xff, 0xff, 0x0a, 0x00, 0x00, 0x00, 0x04, 0x00, 0x00, 0x00,
#   0x13, 0x00, 0x00, 0x00, 0x43, 0x4f, 0x4e, 0x56, 0x45, 0x52, 0x53, 0x49,
#   0x4f, 0x4e, 0x5f, 0x4d, 0x45, 0x54, 0x41, 0x44, 0x41, 0x54, 0x41, 0x00,
#   0x08, 0x00, 0x0c, 0x00, 0x08, 0x00, 0x04, 0x00, 0x08, 0x00, 0x00, 0x00,
#   0x09, 0x00, 0x00, 0x00, 0x04, 0x00, 0x00, 0x00, 0x13, 0x00, 0x00, 0x00,
#   0x6d, 0x69, 0x6e, 0x5f, 0x72, 0x75, 0x6e, 0x74, 0x69, 0x6d, 0x65, 0x5f,
#   0x76, 0x65, 0x72, 0x73, 0x69, 0x6f, 0x6e, 0x00, 0x0b, 0x00, 0x00, 0x00,
#   0x7c, 0x01, 0x00, 0x00, 0x74, 0x01, 0x00, 0x00, 0x1c, 0x01, 0x00, 0x00,
#   0xd4, 0x00, 0x00, 0x00, 0xb8, 0x00, 0x00, 0x00, 0xa4, 0x00, 0x00, 0x00,
#   0x9c, 0x00, 0x00, 0x00, 0x94, 0x00, 0x00, 0x00, 0x8c, 0x00, 0x00, 0x00,
#   0x6c, 0x00, 0x00, 0x00, 0x04, 0x00, 0x00, 0x00, 0x0e, 0xff, 0xff, 0xff,
#   0x04, 0x00, 0x00, 0x00, 0x58, 0x00, 0x00, 0x00, 0x0c, 0x00, 0x00, 0x00,
#   0x08, 0x00, 0x0e, 0x00, 0x08, 0x00, 0x04, 0x00, 0x08, 0x00, 0x00, 0x00,
#   0x10, 0x00, 0x00, 0x00, 0x28, 0x00, 0x00, 0x00, 0x00, 0x00, 0x06, 0x00,
#   0x08, 0x00, 0x04, 0x00, 0x06, 0x00, 0x00, 0x00, 0x04, 0x00, 0x00, 0x00,
#   0x01, 0x00, 0x00, 0x00, 0xeb, 0x03, 0x00, 0x00, 0x00, 0x00, 0x0a, 0x00,
#   0x10, 0x00, 0x0c, 0x00, 0x08, 0x00, 0x04, 0x00, 0x0a, 0x00, 0x00, 0x00,
#   0x01, 0x00, 0x00, 0x00, 0x02, 0x00, 0x00, 0x00, 0x04, 0x00, 0x00, 0x00,
#   0x05, 0x00, 0x00, 0x00, 0x32, 0x2e, 0x39, 0x2e, 0x32, 0x00, 0x00, 0x00,
#   0x72, 0xff, 0xff, 0xff, 0x04, 0x00, 0x00, 0x00, 0x10, 0x00, 0x00, 0x00,
#   0x31, 0x2e, 0x31, 0x34, 0x2e, 0x30, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00,
#   0x00, 0x00, 0x00, 0x00, 0x8c, 0xfe, 0xff, 0xff, 0x90, 0xfe, 0xff, 0xff,
#   0x94, 0xfe, 0xff, 0xff, 0x9a, 0xff, 0xff, 0xff, 0x04, 0x00, 0x00, 0x00,
#   0x04, 0x00, 0x00, 0x00, 0x0a, 0x04, 0x00, 0x00, 0xaa, 0xff, 0xff, 0xff,
#   0x04, 0x00, 0x00, 0x00, 0x0c, 0x00, 0x00, 0x00, 0xb2, 0xe3, 0x2c, 0x81,
#   0xbf, 0x2d, 0x1b, 0xc9, 0x23, 0x1e, 0x0c, 0x85, 0xc2, 0xff, 0xff, 0xff,
#   0x04, 0x00, 0x00, 0x00, 0x30, 0x00, 0x00, 0x00, 0x47, 0x0a, 0x00, 0x00,
#   0x04, 0xfb, 0xff, 0xff, 0x76, 0x02, 0x00, 0x00, 0xea, 0x0a, 0x00, 0x00,
#   0x3e, 0x0b, 0x00, 0x00, 0x26, 0x03, 0x00, 0x00, 0x07, 0xfe, 0xff, 0xff,
#   0xe2, 0x0d, 0x00, 0x00, 0x15, 0x02, 0x00, 0x00, 0x93, 0xfc, 0xff, 0xff,
#   0x0e, 0xfd, 0xff, 0xff, 0x8b, 0x08, 0x00, 0x00, 0x00, 0x00, 0x06, 0x00,
#   0x08, 0x00, 0x04, 0x00, 0x06, 0x00, 0x00, 0x00, 0x04, 0x00, 0x00, 0x00,
#   0x48, 0x00, 0x00, 0x00, 0x31, 0x1e, 0x57, 0x04, 0xe7, 0x1b, 0xfc, 0xe4,
#   0xf2, 0xef, 0x19, 0xed, 0x07, 0xfe, 0xd2, 0xe8, 0xfd, 0x14, 0x17, 0x0d,
#   0x7f, 0xef, 0x2a, 0xe9, 0x46, 0x18, 0x58, 0xf5, 0x11, 0x01, 0x19, 0xdc,
#   0xe6, 0x06, 0xf9, 0xfd, 0x1d, 0xe8, 0xf8, 0x0f, 0x04, 0x1f, 0x1d, 0x43,
#   0x74, 0x18, 0xe2, 0x0b, 0xfa, 0xfd, 0xce, 0x10, 0xf7, 0xf7, 0xe6, 0x0c,
#   0x0b, 0x1e, 0x16, 0x29, 0x12, 0x18, 0xf8, 0x02, 0xfb, 0x08, 0x25, 0x25,
#   0x3f, 0x08, 0x18, 0xe4, 0x58, 0xff, 0xff, 0xff, 0x5c, 0xff, 0xff, 0xff,
#   0x0f, 0x00, 0x00, 0x00, 0x4d, 0x4c, 0x49, 0x52, 0x20, 0x43, 0x6f, 0x6e,
#   0x76, 0x65, 0x72, 0x74, 0x65, 0x64, 0x2e, 0x00, 0x01, 0x00, 0x00, 0x00,
#   0x14, 0x00, 0x00, 0x00, 0x00, 0x00, 0x0e, 0x00, 0x18, 0x00, 0x14, 0x00,
#   0x10, 0x00, 0x0c, 0x00, 0x08, 0x00, 0x04, 0x00, 0x0e, 0x00, 0x00, 0x00,
#   0x14, 0x00, 0x00, 0x00, 0x1c, 0x00, 0x00, 0x00, 0xd4, 0x00, 0x00, 0x00,
#   0xd8, 0x00, 0x00, 0x00, 0xdc, 0x00, 0x00, 0x00, 0x04, 0x00, 0x00, 0x00,
#   0x6d, 0x61, 0x69, 0x6e, 0x00, 0x00, 0x00, 0x00, 0x03, 0x00, 0x00, 0x00,
#   0x7c, 0x00, 0x00, 0x00, 0x34, 0x00, 0x00, 0x00, 0x10, 0x00, 0x00, 0x00,
#   0x00, 0x00, 0x0a, 0x00, 0x10, 0x00, 0x0c, 0x00, 0x08, 0x00, 0x04, 0x00,
#   0x0a, 0x00, 0x00, 0x00, 0x0c, 0x00, 0x00, 0x00, 0x10, 0x00, 0x00, 0x00,
#   0x01, 0x00, 0x00, 0x00, 0x01, 0x00, 0x00, 0x00, 0x07, 0x00, 0x00, 0x00,
#   0x01, 0x00, 0x00, 0x00, 0x06, 0x00, 0x00, 0x00, 0xca, 0xff, 0xff, 0xff,
#   0x14, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x08, 0x10, 0x00, 0x00, 0x00,
#   0x14, 0x00, 0x00, 0x00, 0x04, 0x00, 0x04, 0x00, 0x04, 0x00, 0x00, 0x00,
#   0x01, 0x00, 0x00, 0x00, 0x06, 0x00, 0x00, 0x00, 0x03, 0x00, 0x00, 0x00,
#   0x05, 0x00, 0x00, 0x00, 0x03, 0x00, 0x00, 0x00, 0x04, 0x00, 0x00, 0x00,
#   0x00, 0x00, 0x0e, 0x00, 0x16, 0x00, 0x00, 0x00, 0x10, 0x00, 0x0c, 0x00,
#   0x0b, 0x00, 0x04, 0x00, 0x0e, 0x00, 0x00, 0x00, 0x18, 0x00, 0x00, 0x00,
#   0x00, 0x00, 0x00, 0x08, 0x18, 0x00, 0x00, 0x00, 0x1c, 0x00, 0x00, 0x00,
#   0x00, 0x00, 0x06, 0x00, 0x08, 0x00, 0x07, 0x00, 0x06, 0x00, 0x00, 0x00,
#   0x00, 0x00, 0x00, 0x01, 0x01, 0x00, 0x00, 0x00, 0x05, 0x00, 0x00, 0x00,
#   0x03, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x01, 0x00, 0x00, 0x00,
#   0x02, 0x00, 0x00, 0x00, 0x01, 0x00, 0x00, 0x00, 0x07, 0x00, 0x00, 0x00,
#   0x01, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x08, 0x00, 0x00, 0x00,
#   0x94, 0x03, 0x00, 0x00, 0x1c, 0x03, 0x00, 0x00, 0x98, 0x02, 0x00, 0x00,
#   0x2c, 0x02, 0x00, 0x00, 0xb8, 0x01, 0x00, 0x00, 0x14, 0x01, 0x00, 0x00,
#   0x80, 0x00, 0x00, 0x00, 0x04, 0x00, 0x00, 0x00, 0xa0, 0xfc, 0xff, 0xff,
#   0x18, 0x00, 0x00, 0x00, 0x20, 0x00, 0x00, 0x00, 0x40, 0x00, 0x00, 0x00,
#   0x08, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x09, 0x54, 0x00, 0x00, 0x00,
#   0x02, 0x00, 0x00, 0x00, 0xff, 0xff, 0xff, 0xff, 0x01, 0x00, 0x00, 0x00,
#   0x8c, 0xfc, 0xff, 0xff, 0x08, 0x00, 0x00, 0x00, 0x14, 0x00, 0x00, 0x00,
#   0x01, 0x00, 0x00, 0x00, 0x80, 0xff, 0xff, 0xff, 0xff, 0xff, 0xff, 0xff,
#   0x00, 0x00, 0x00, 0x00, 0x01, 0x00, 0x00, 0x00, 0x00, 0x00, 0x80, 0x3b,
#   0x19, 0x00, 0x00, 0x00, 0x53, 0x74, 0x61, 0x74, 0x65, 0x66, 0x75, 0x6c,
#   0x50, 0x61, 0x72, 0x74, 0x69, 0x74, 0x69, 0x6f, 0x6e, 0x65, 0x64, 0x43,
#   0x61, 0x6c, 0x6c, 0x3a, 0x30, 0x00, 0x00, 0x00, 0x02, 0x00, 0x00, 0x00,
#   0x01, 0x00, 0x00, 0x00, 0x01, 0x00, 0x00, 0x00, 0x18, 0xfd, 0xff, 0xff,
#   0x18, 0x00, 0x00, 0x00, 0x20, 0x00, 0x00, 0x00, 0x3c, 0x00, 0x00, 0x00,
#   0x07, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x09, 0x6c, 0x00, 0x00, 0x00,
#   0x02, 0x00, 0x00, 0x00, 0xff, 0xff, 0xff, 0xff, 0x01, 0x00, 0x00, 0x00,
#   0x04, 0xfd, 0xff, 0xff, 0x08, 0x00, 0x00, 0x00, 0x10, 0x00, 0x00, 0x00,
#   0x01, 0x00, 0x00, 0x00, 0x6c, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00,
#   0x01, 0x00, 0x00, 0x00, 0x53, 0x3f, 0x36, 0x3e, 0x34, 0x00, 0x00, 0x00,
#   0x73, 0x65, 0x71, 0x75, 0x65, 0x6e, 0x74, 0x69, 0x61, 0x6c, 0x2f, 0x64,
#   0x65, 0x6e, 0x73, 0x65, 0x5f, 0x31, 0x2f, 0x4d, 0x61, 0x74, 0x4d, 0x75,
#   0x6c, 0x3b, 0x73, 0x65, 0x71, 0x75, 0x65, 0x6e, 0x74, 0x69, 0x61, 0x6c,
#   0x2f, 0x64, 0x65, 0x6e, 0x73, 0x65, 0x5f, 0x31, 0x2f, 0x42, 0x69, 0x61,
#   0x73, 0x41, 0x64, 0x64, 0x00, 0x00, 0x00, 0x00, 0x02, 0x00, 0x00, 0x00,
#   0x01, 0x00, 0x00, 0x00, 0x01, 0x00, 0x00, 0x00, 0xa8, 0xfd, 0xff, 0xff,
#   0x18, 0x00, 0x00, 0x00, 0x20, 0x00, 0x00, 0x00, 0x3c, 0x00, 0x00, 0x00,
#   0x06, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x09, 0x7c, 0x00, 0x00, 0x00,
#   0x02, 0x00, 0x00, 0x00, 0xff, 0xff, 0xff, 0xff, 0x0c, 0x00, 0x00, 0x00,
#   0x94, 0xfd, 0xff, 0xff, 0x08, 0x00, 0x00, 0x00, 0x10, 0x00, 0x00, 0x00,
#   0x01, 0x00, 0x00, 0x00, 0x80, 0xff, 0xff, 0xff, 0xff, 0xff, 0xff, 0xff,
#   0x01, 0x00, 0x00, 0x00, 0x9d, 0x00, 0x00, 0x3d, 0x46, 0x00, 0x00, 0x00,
#   0x73, 0x65, 0x71, 0x75, 0x65, 0x6e, 0x74, 0x69, 0x61, 0x6c, 0x2f, 0x64,
#   0x65, 0x6e, 0x73, 0x65, 0x2f, 0x4d, 0x61, 0x74, 0x4d, 0x75, 0x6c, 0x3b,
#   0x73, 0x65, 0x71, 0x75, 0x65, 0x6e, 0x74, 0x69, 0x61, 0x6c, 0x2f, 0x64,
#   0x65, 0x6e, 0x73, 0x65, 0x2f, 0x52, 0x65, 0x6c, 0x75, 0x3b, 0x73, 0x65,
#   0x71, 0x75, 0x65, 0x6e, 0x74, 0x69, 0x61, 0x6c, 0x2f, 0x64, 0x65, 0x6e,
#   0x73, 0x65, 0x2f, 0x42, 0x69, 0x61, 0x73, 0x41, 0x64, 0x64, 0x00, 0x00,
#   0x02, 0x00, 0x00, 0x00, 0x01, 0x00, 0x00, 0x00, 0x0c, 0x00, 0x00, 0x00,
#   0xb6, 0xfe, 0xff, 0xff, 0x14, 0x00, 0x00, 0x00, 0x30, 0x00, 0x00, 0x00,
#   0x05, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x02, 0x54, 0x00, 0x00, 0x00,
#   0x24, 0xfe, 0xff, 0xff, 0x08, 0x00, 0x00, 0x00, 0x10, 0x00, 0x00, 0x00,
#   0x01, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00,
#   0x01, 0x00, 0x00, 0x00, 0x28, 0x3d, 0x01, 0x3a, 0x29, 0x00, 0x00, 0x00,
#   0x73, 0x65, 0x71, 0x75, 0x65, 0x6e, 0x74, 0x69, 0x61, 0x6c, 0x2f, 0x64,
#   0x65, 0x6e, 0x73, 0x65, 0x5f, 0x31, 0x2f, 0x42, 0x69, 0x61, 0x73, 0x41,
#   0x64, 0x64, 0x2f, 0x52, 0x65, 0x61, 0x64, 0x56, 0x61, 0x72, 0x69, 0x61,
#   0x62, 0x6c, 0x65, 0x4f, 0x70, 0x00, 0x00, 0x00, 0x01, 0x00, 0x00, 0x00,
#   0x01, 0x00, 0x00, 0x00, 0x26, 0xff, 0xff, 0xff, 0x14, 0x00, 0x00, 0x00,
#   0x34, 0x00, 0x00, 0x00, 0x04, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x09,
#   0x48, 0x00, 0x00, 0x00, 0x94, 0xfe, 0xff, 0xff, 0x08, 0x00, 0x00, 0x00,
#   0x14, 0x00, 0x00, 0x00, 0x01, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00,
#   0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x01, 0x00, 0x00, 0x00,
#   0x89, 0x3c, 0x81, 0x3c, 0x19, 0x00, 0x00, 0x00, 0x73, 0x65, 0x71, 0x75,
#   0x65, 0x6e, 0x74, 0x69, 0x61, 0x6c, 0x2f, 0x64, 0x65, 0x6e, 0x73, 0x65,
#   0x5f, 0x31, 0x2f, 0x4d, 0x61, 0x74, 0x4d, 0x75, 0x6c, 0x00, 0x00, 0x00,
#   0x02, 0x00, 0x00, 0x00, 0x01, 0x00, 0x00, 0x00, 0x0c, 0x00, 0x00, 0x00,
#   0x8e, 0xff, 0xff, 0xff, 0x14, 0x00, 0x00, 0x00, 0x34, 0x00, 0x00, 0x00,
#   0x03, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x02, 0x54, 0x00, 0x00, 0x00,
#   0xfc, 0xfe, 0xff, 0xff, 0x08, 0x00, 0x00, 0x00, 0x14, 0x00, 0x00, 0x00,
#   0x01, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00,
#   0x00, 0x00, 0x00, 0x00, 0x01, 0x00, 0x00, 0x00, 0xb1, 0xc6, 0x9c, 0x39,
#   0x27, 0x00, 0x00, 0x00, 0x73, 0x65, 0x71, 0x75, 0x65, 0x6e, 0x74, 0x69,
#   0x61, 0x6c, 0x2f, 0x64, 0x65, 0x6e, 0x73, 0x65, 0x2f, 0x42, 0x69, 0x61,
#   0x73, 0x41, 0x64, 0x64, 0x2f, 0x52, 0x65, 0x61, 0x64, 0x56, 0x61, 0x72,
#   0x69, 0x61, 0x62, 0x6c, 0x65, 0x4f, 0x70, 0x00, 0x01, 0x00, 0x00, 0x00,
#   0x0c, 0x00, 0x00, 0x00, 0x00, 0x00, 0x0e, 0x00, 0x18, 0x00, 0x14, 0x00,
#   0x13, 0x00, 0x0c, 0x00, 0x08, 0x00, 0x04, 0x00, 0x0e, 0x00, 0x00, 0x00,
#   0x14, 0x00, 0x00, 0x00, 0x30, 0x00, 0x00, 0x00, 0x02, 0x00, 0x00, 0x00,
#   0x00, 0x00, 0x00, 0x09, 0x40, 0x00, 0x00, 0x00, 0x7c, 0xff, 0xff, 0xff,
#   0x08, 0x00, 0x00, 0x00, 0x10, 0x00, 0x00, 0x00, 0x01, 0x00, 0x00, 0x00,
#   0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x01, 0x00, 0x00, 0x00,
#   0x81, 0x6b, 0x62, 0x3c, 0x17, 0x00, 0x00, 0x00, 0x73, 0x65, 0x71, 0x75,
#   0x65, 0x6e, 0x74, 0x69, 0x61, 0x6c, 0x2f, 0x64, 0x65, 0x6e, 0x73, 0x65,
#   0x2f, 0x4d, 0x61, 0x74, 0x4d, 0x75, 0x6c, 0x00, 0x02, 0x00, 0x00, 0x00,
#   0x0c, 0x00, 0x00, 0x00, 0x06, 0x00, 0x00, 0x00, 0x14, 0x00, 0x1c, 0x00,
#   0x18, 0x00, 0x17, 0x00, 0x10, 0x00, 0x0c, 0x00, 0x08, 0x00, 0x00, 0x00,
#   0x00, 0x00, 0x04, 0x00, 0x14, 0x00, 0x00, 0x00, 0x18, 0x00, 0x00, 0x00,
#   0x2c, 0x00, 0x00, 0x00, 0x48, 0x00, 0x00, 0x00, 0x01, 0x00, 0x00, 0x00,
#   0x00, 0x00, 0x00, 0x09, 0x60, 0x00, 0x00, 0x00, 0x02, 0x00, 0x00, 0x00,
#   0xff, 0xff, 0xff, 0xff, 0x06, 0x00, 0x00, 0x00, 0x0c, 0x00, 0x0c, 0x00,
#   0x00, 0x00, 0x00, 0x00, 0x08, 0x00, 0x04, 0x00, 0x0c, 0x00, 0x00, 0x00,
#   0x08, 0x00, 0x00, 0x00, 0x10, 0x00, 0x00, 0x00, 0x01, 0x00, 0x00, 0x00,
#   0x0d, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x01, 0x00, 0x00, 0x00,
#   0xfd, 0x41, 0xb1, 0x3c, 0x1d, 0x00, 0x00, 0x00, 0x73, 0x65, 0x72, 0x76,
#   0x69, 0x6e, 0x67, 0x5f, 0x64, 0x65, 0x66, 0x61, 0x75, 0x6c, 0x74, 0x5f,
#   0x64, 0x65, 0x6e, 0x73, 0x65, 0x5f, 0x69, 0x6e, 0x70, 0x75, 0x74, 0x3a,
#   0x30, 0x00, 0x00, 0x00, 0x02, 0x00, 0x00, 0x00, 0x01, 0x00, 0x00, 0x00,
#   0x06, 0x00, 0x00, 0x00, 0x02, 0x00, 0x00, 0x00, 0x24, 0x00, 0x00, 0x00,
#   0x04, 0x00, 0x00, 0x00, 0xf0, 0xff, 0xff, 0xff, 0x0e, 0x00, 0x00, 0x00,
#   0x02, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x0e, 0x0c, 0x00, 0x10, 0x00,
#   0x0f, 0x00, 0x00, 0x00, 0x08, 0x00, 0x04, 0x00, 0x0c, 0x00, 0x00, 0x00,
#   0x09, 0x00, 0x00, 0x00, 0x04, 0x00, 0x00, 0x00, 0x00, 0x00, 0x00, 0x09
# };
# unsigned int snow_forecast_model_tflite_len = 2040;
